# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\e3027859\\Most-Recent-Cohorts-Scorecard-Elements.csv', index_col=0)
df.head()
# Out:
#           OPEID  OPEID6                               INSTNM        CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University      Normal
# 100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 100690  2503400   25034                   Amridge University  Montgomery
# 100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 100724   100500    1005             Alabama State University  Montgomery
#
#        STABBR                    INSTURL  \
# UNITID
# 100654     AL              www.aamu.edu/
# 100663     AL                www.uab.edu
# 100690     AL  www.amridgeuniversity.edu
# 100706     AL                www.uah.edu
# 100724     AL              www.alasu.edu
#
#                                                    NPCURL  HCM2  PREDDEG  \
# UNITID
# 100654      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 100663           uab.studentaidcalculator.com/survey.aspx     0        3
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of              OPEID  OPEID6                                             INSTNM  \
# UNITID
# 100654      100200    1002                           Alabama A & M University
# 100663      105200    1052                University of Alabama at Birmingham
# 100690     2503400   25034                                 Amridge University
# 100706      105500    1055                University of Alabama in Huntsville
# 100724      100500    1005                           Alabama State University
# 100751      105100    1051                          The University of Alabama
# 100760      100700    1007                  Central Alabama Community College
# 100812      100800    1008                            Athens State University
# 100830      831000    8310                    Auburn University at Montgomery
# 100858      100900    1009                                  Auburn University
# ...

# %%
df['CITY'].head()
# Out:
# UNITID
# 100654        Normal
# 100663    Birmingham
# 100690    Montgomery
# 100706    Huntsville
# 100724    Montgomery
# Name: CITY, dtype: object

# %%
college_race = df.loc[:, 'OPEID':'CITY']
college_race.head()
# Out:
#           OPEID  OPEID6                               INSTNM        CITY
# UNITID
# 100654   100200    1002             Alabama A & M University      Normal
# 100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 100690  2503400   25034                   Amridge University  Montgomery
# 100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 100724   100500    1005             Alabama State University  Montgomery

# %%
ugds = college_race['OPEID'].dropna()
ugds.head()
# Out:
# UNITID
# 100654     100200
# 100663     105200
# 100690    2503400
# 100706     105500
# 100724     100500
# Name: OPEID, dtype: int64

# %%
 df.groupby('CITY')['PREDDEG'].agg('max').head()
# Out:
# CITY
# ARTESIA     1
# Aberdeen    3
# Abilene     3
# Abingdon    1
# Abington    3
# Name: PREDDEG, dtype: int64

# %%
df.groupby('CITY').agg({'HCM2': 'max','PREDDEG': 'min'}).head()
# Out:
#           HCM2  PREDDEG
# SATMTMID
# 355.0        0        1
# 360.0        0        3
# 365.0        0        3
# 370.0        0        2
# 375.0        0        2

# %%
agg_dict = {'SATMTMID': ['min', 'max'],
                'SATVRMID': ['min', 'max'],
                'UGDS': 'mean'}
df2 = df.groupby(['STABBR', 'RELAFFIL']).agg(agg_dict)
df2.head(10).round(0)
# Out:
#                 SATMTMID        SATVRMID           UGDS
#                      min    max      min    max    mean
# STABBR RELAFFIL
# AK     37.0          NaN    NaN      NaN    NaN    79.0
#        71.0          NaN    NaN      NaN    NaN   262.0
#        88.0          NaN    NaN      NaN    NaN    33.0
# AL     30.0        545.0  545.0    550.0  550.0  1379.0
#        42.0          NaN    NaN      NaN    NaN   119.0
#        54.0        531.0  559.0    570.0  581.0  1272.0
#        55.0          NaN    NaN      NaN    NaN  1820.0
#        66.0        420.0  420.0    405.0  405.0   628.0
#        68.0          NaN    NaN      NaN    NaN   340.0
#        71.0        475.0  530.0    473.0  555.0  1214.0

# %%
df2.columns = ['min satmtmid', 'max satmtmid', 'min satvrmid',         
                   'max satvrmid', 'mean ugds']
df2.head()
# Out:
#                  min satmtmid  max satmtmid  min satvrmid  max satvrmid  \
# STABBR RELAFFIL
# AK     37.0               NaN           NaN           NaN           NaN
#        71.0               NaN           NaN           NaN           NaN
#        88.0               NaN           NaN           NaN           NaN
# AL     30.0             545.0         545.0         550.0         550.0
#        42.0               NaN           NaN           NaN           NaN
#
#                  mean ugds
# STABBR RELAFFIL
# AK     37.0           79.0
#        71.0          262.0
#        88.0           33.0
# AL     30.0         1379.0
#        42.0          119.0

# %%
df2.reset_index().head()
# Out:
#   STABBR  RELAFFIL  min satmtmid  max satmtmid  min satvrmid  max satvrmid  \
# 0     AK      37.0           NaN           NaN           NaN           NaN
# 1     AK      71.0           NaN           NaN           NaN           NaN
# 2     AK      88.0           NaN           NaN           NaN           NaN
# 3     AL      30.0         545.0         545.0         550.0         550.0
# 4     AL      42.0           NaN           NaN           NaN           NaN
#
#    mean ugds
# 0       79.0
# 1      262.0
# 2       33.0
# 3     1379.0
# 4      119.0

# %%
df.columns
# Out:
# Index(['OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'INSTURL', 'NPCURL',
#        'HCM2', 'PREDDEG', 'HIGHDEG',
#        ...
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GT_25K_P6', 'GT_28K_P6',
#        'GRAD_DEBT_MDN_SUPP', 'GRAD_DEBT_MDN10YR_SUPP', 'RPY_3YR_RT_SUPP',
#        'C150_L4_POOLED_SUPP', 'C150_4_POOLED_SUPP'],
#       dtype='object', length=123)

# %%
columns=df2.columns

# %%
columns
# Out:
# Index(['min satmtmid', 'max satmtmid', 'min satvrmid', 'max satvrmid',
#        'mean ugds'],
#       dtype='object')

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df2[['min satmtmid', 'max satmtmid', 'min satvrmid', 'max satvrmid',
       'mean ugds']]
# Out:
#                  min satmtmid  max satmtmid  min satvrmid  max satvrmid  \
# STABBR RELAFFIL
# AK     37.0               NaN           NaN           NaN           NaN
#        71.0               NaN           NaN           NaN           NaN
#        88.0               NaN           NaN           NaN           NaN
# AL     30.0             545.0         545.0         550.0         550.0
#        42.0               NaN           NaN           NaN           NaN
#        54.0             531.0         559.0         570.0         581.0
#        55.0               NaN           NaN           NaN           NaN
#        66.0             420.0         420.0         405.0         405.0
#        68.0               NaN           NaN           NaN           NaN
#        71.0             475.0         530.0         473.0         555.0
#        74.0             500.0         500.0         500.0         500.0
#        75.0             500.0         500.0         485.0         485.0
# ...

# %%
df2.loc[['AK','AL']]
# Out:
#                  min satmtmid  max satmtmid  min satvrmid  max satvrmid  \
# STABBR RELAFFIL
# AK     37.0               NaN           NaN           NaN           NaN
#        71.0               NaN           NaN           NaN           NaN
#        88.0               NaN           NaN           NaN           NaN
# AL     30.0             545.0         545.0         550.0         550.0
#        42.0               NaN           NaN           NaN           NaN
#        54.0             531.0         559.0         570.0         581.0
#        55.0               NaN           NaN           NaN           NaN
#        66.0             420.0         420.0         405.0         405.0
#        68.0               NaN           NaN           NaN           NaN
#        71.0             475.0         530.0         473.0         555.0
#        74.0             500.0         500.0         500.0         500.0
#        75.0             500.0         500.0         485.0         485.0
# ...

# %%
df.head()
# Out:
#           OPEID  OPEID6                               INSTNM        CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University      Normal
# 100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 100690  2503400   25034                   Amridge University  Montgomery
# 100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 100724   100500    1005             Alabama State University  Montgomery
#
#        STABBR                    INSTURL  \
# UNITID
# 100654     AL              www.aamu.edu/
# 100663     AL                www.uab.edu
# 100690     AL  www.amridgeuniversity.edu
# 100706     AL                www.uah.edu
# 100724     AL              www.alasu.edu
#
#                                                    NPCURL  HCM2  PREDDEG  \
# UNITID
# 100654      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 100663           uab.studentaidcalculator.com/survey.aspx     0        3
# ...

# %%
df.loc[[100654,100690], ['CITY', 'STABBR', 'INSTNM']]
# Out:
#               CITY STABBR                    INSTNM
# UNITID
# 100654      Normal     AL  Alabama A & M University
# 100690  Montgomery     AL        Amridge University

# %%
df.loc[[100654,100690], :]
# Out:
#           OPEID  OPEID6                    INSTNM        CITY STABBR  \
# UNITID
# 100654   100200    1002  Alabama A & M University      Normal     AL
# 100690  2503400   25034        Amridge University  Montgomery     AL
#
#                           INSTURL  \
# UNITID
# 100654              www.aamu.edu/
# 100690  www.amridgeuniversity.edu
#
#                                                NPCURL  HCM2  PREDDEG  HIGHDEG  \
# UNITID
# 100654  www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3        4
# 100690               www2.amridgeuniversity.edu:9091/     0        3        4
#
#                ...          PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GT_25K_P6  \
# UNITID         ...
# 100654         ...            0.7667   0.0859            31000      0.453
# 100690         ...            0.8436   0.8571            39600      0.658
#
#         GT_28K_P6  GRAD_DEBT_MDN_SUPP  GRAD_DEBT_MDN10YR_SUPP  \
# UNITID
# 100654      0.431               32750         348.16551225731
# ...

# %%
df2_idx = df.set_index('CITY')

# %%
df2_idx.head(10)
# Out:
#                   OPEID  OPEID6                               INSTNM STABBR  \
# CITY
# Normal           100200    1002             Alabama A & M University     AL
# Birmingham       105200    1052  University of Alabama at Birmingham     AL
# Montgomery      2503400   25034                   Amridge University     AL
# Huntsville       105500    1055  University of Alabama in Huntsville     AL
# Montgomery       100500    1005             Alabama State University     AL
# Tuscaloosa       105100    1051            The University of Alabama     AL
# Alexander City   100700    1007    Central Alabama Community College     AL
# Athens           100800    1008              Athens State University     AL
# Montgomery       831000    8310      Auburn University at Montgomery     AL
# Auburn           100900    1009                    Auburn University     AL
#
#                                   INSTURL  \
# CITY
# Normal                      www.aamu.edu/
# ...

# %%
df.rename(columns={'CITY': 'citylatest', 'HCM2': 'HCM3'}, inplace=True)

# %%
df.head()
# Out:
#           OPEID  OPEID6                               INSTNM  citylatest  \
# UNITID
# 100654   100200    1002             Alabama A & M University      Normal
# 100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 100690  2503400   25034                   Amridge University  Montgomery
# 100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 100724   100500    1005             Alabama State University  Montgomery
#
#        STABBR                    INSTURL  \
# UNITID
# 100654     AL              www.aamu.edu/
# 100663     AL                www.uab.edu
# 100690     AL  www.amridgeuniversity.edu
# 100706     AL                www.uah.edu
# 100724     AL              www.alasu.edu
#
#                                                    NPCURL  HCM3  PREDDEG  \
# UNITID
# 100654      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 100663           uab.studentaidcalculator.com/survey.aspx     0        3
# ...

# %%
df.sort_values(by=['citylatest', 'STABBR'])
# Out:
#             OPEID  OPEID6                                             INSTNM  \
# UNITID
# 457314    4164400   41644                                  Angeles Institute
# 219259     346600    3466                          Northern State University
# 219295     346700    3467                               Presentation College
# 235334     377900    3779                               Grays Harbor College
# 222178     353700    3537                       Abilene Christian University
# 225247     357100    3571                          Hardin-Simmons University
# 226587     359100    3591                                 McMurry University
# 377315    3025000   30250               Texas College of Cosmetology-Abilene
# 483513    4231200   42312                    NeeCee's College of Cosmetology
# 233903     709900    7099               Virginia Highlands Community College
# 214801     332913    3329  Pennsylvania State University-Penn State Abington
# ...

# %%
df['STABBR'].unique()
# Out:
# array(['AL', 'IL', 'AK', 'WA', 'AZ', 'NM', 'AR', 'CA', 'MN', 'CO', 'CT',
#        'NY', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IN', 'MI', 'IA', 'KS',
#        'MO', 'KY', 'LA', 'ME', 'MD', 'MA', 'MS', 'MT', 'NE', 'NV', 'NH',
#        'NJ', 'NC', 'ND', 'OH', 'WV', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD',
#        'TN', 'TX', 'UT', 'VT', 'VA', 'WI', 'WY', 'AS', 'GU', 'MP', 'PR',
#        'FM', 'PW', 'VI', 'MH'], dtype=object)

# %%
df['citylatest'].isna().sum()
# Out:
# 0

# %%
df.isna().any()
# Out:
# OPEID                     False
# OPEID6                    False
# INSTNM                    False
# citylatest                False
# STABBR                    False
# INSTURL                    True
# NPCURL                     True
# HCM3                      False
# PREDDEG                   False
# HIGHDEG                   False
# CONTROL                   False
# LOCALE                     True
# HBCU                       True
# PBI                        True
# ANNHI                      True
# TRIBAL                     True
# AANAPII                    True
# HSI                        True
# NANTI                      True
# MENONLY                    True
# WOMENONLY                  True
# RELAFFIL                   True
# SATVR25                    True
# SATVR75                    True
# SATMT25                    True
# SATMT75                    True
# SATWR25                    True
# SATWR75                    True
# SATVRMID                   True
# ...

# %%
df.loc[:, df.isna().any()]
# Out:
#                                                     INSTURL  \
# UNITID
# 100654                                        www.aamu.edu/
# 100663                                          www.uab.edu
# 100690                            www.amridgeuniversity.edu
# 100706                                          www.uah.edu
# 100724                                        www.alasu.edu
# 100751                                          www.ua.edu/
# 100760                                         www.cacc.edu
# 100812                                       www.athens.edu
# 100830                                          www.aum.edu
# 100858                                       www.auburn.edu
# 100937                                         www.bsc.edu/
# 101028                                           www.cv.edu
# 101073                                        www.ccal.edu/
# 101116    www.southuniversity.edu/montgomery#location=Mo...
# ...

# %%
df[df['citylatest'].isnull()]
# Out:
# Empty DataFrame
# Columns: [OPEID, OPEID6, INSTNM, citylatest, STABBR, INSTURL, NPCURL, HCM3, PREDDEG, HIGHDEG, CONTROL, LOCALE, HBCU, PBI, ANNHI, TRIBAL, AANAPII, HSI, NANTI, MENONLY, WOMENONLY, RELAFFIL, SATVR25, SATVR75, SATMT25, SATMT75, SATWR25, SATWR75, SATVRMID, SATMTMID, SATWRMID, ACTCM25, ACTCM75, ACTEN25, ACTEN75, ACTMT25, ACTMT75, ACTWR25, ACTWR75, ACTCMMID, ACTENMID, ACTMTMID, ACTWRMID, SAT_AVG, SAT_AVG_ALL, PCIP01, PCIP03, PCIP04, PCIP05, PCIP09, PCIP10, PCIP11, PCIP12, PCIP13, PCIP14, PCIP15, PCIP16, PCIP19, PCIP22, PCIP23, PCIP24, PCIP25, PCIP26, PCIP27, PCIP29, PCIP30, PCIP31, PCIP38, PCIP39, PCIP40, PCIP41, PCIP42, PCIP43, PCIP44, PCIP45, PCIP46, PCIP47, PCIP48, PCIP49, PCIP50, PCIP51, PCIP52, PCIP54, DISTANCEONLY, UGDS, UGDS_WHITE, UGDS_BLACK, UGDS_HISP, UGDS_ASIAN, UGDS_AIAN, UGDS_NHPI, UGDS_2MOR, UGDS_NRA, UGDS_UNKN, PPTUG_EF, CURROPER, NPT4_PUB, NPT4_PRIV, NPT41_PUB, NPT42_PUB, ...]
# Index: []
#
# [0 rows x 123 columns]

# %%
df.tail(n=2)
# Out:
#             OPEID  OPEID6                       INSTNM   citylatest STABBR  \
# UNITID
# 48414501  4232401   42324  Vantage College-San Antonio  San Antonio     TX
# 48778201  4221501   42215                 BCI - Malden       Malden     MA
#
#                    INSTURL NPCURL  HCM3  PREDDEG  HIGHDEG         ...          \
# UNITID                                                            ...
# 48414501   www.vantage.edu    NaN     0        0        0         ...
# 48778201  bostoncareer.org    NaN     0        0        0         ...
#
#           PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GT_25K_P6  GT_28K_P6  \
# UNITID
# 48414501       NaN      NaN              NaN        NaN        NaN
# 48778201       NaN      NaN              NaN        NaN        NaN
#
#           GRAD_DEBT_MDN_SUPP  GRAD_DEBT_MDN10YR_SUPP  RPY_3YR_RT_SUPP  \
# UNITID
# 48414501              9891.5        105.156615709715              NaN
# 48778201   PrivacySuppressed       PrivacySuppressed              NaN
#
# ...

# %%
import pyarrow.parquet as pq
df.to_parquet('data.parquet')
df = pq.read_table('data.parquet').to_pandas()

# %%
df.head()
# Out:
#           OPEID  OPEID6                               INSTNM  citylatest  \
# UNITID
# 100654   100200    1002             Alabama A & M University      Normal
# 100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 100690  2503400   25034                   Amridge University  Montgomery
# 100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 100724   100500    1005             Alabama State University  Montgomery
#
#        STABBR                    INSTURL  \
# UNITID
# 100654     AL              www.aamu.edu/
# 100663     AL                www.uab.edu
# 100690     AL  www.amridgeuniversity.edu
# 100706     AL                www.uah.edu
# 100724     AL              www.alasu.edu
#
#                                                    NPCURL  HCM3  PREDDEG  \
# UNITID
# 100654      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 100663           uab.studentaidcalculator.com/survey.aspx     0        3
# ...

# %%
df.to_csv('file.csv', index=False)
